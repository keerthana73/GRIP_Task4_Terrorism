# %% [markdown]
# # GRIP MAY 2021
#
# ## DATA SCIENCE AND BUSINESS ANALYTICS INTERNSHIP
#
# ## TASK-4 EDA-GLOBAL TERRORISM ANALYSIS
#
# #### DONE BY: KEERTHANA S

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Keerthana\DATASETS& STATS\Global_Terrorism_Data.csv",encoding='latin1',low_memory=False)
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  1.970000e+11   1970       7     2        NaN         0        NaN       58
# 1  1.970000e+11   1970       0     0        NaN         0        NaN      130
# 2  1.970010e+11   1970       1     0        NaN         0        NaN      160
# 3  1.970010e+11   1970       1     0        NaN         0        NaN       78
# 4  1.970010e+11   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(56), int64(21), object(58)
# memory usage: 187.1+ MB

# %% [markdown]
# # EDA

# %%
sns.heatmap(df.corr(),cmap='coolwarm')
plt.show()

# %%
df['iyear'].value_counts().plot(kind='pie',figsize=(7,10)).invert_yaxis()
plt.title('Year with Max Attacks')
# Out:
# Text(0.5, 1.0, 'Year with Max Attacks')

# %%
df['imonth'].value_counts().plot(kind='pie').invert_yaxis()

# %% [markdown]
# ### Region of Attack

# %%
df['region_txt'].value_counts().plot(kind='barh').invert_yaxis()

# %%
df['country_txt'].value_counts().plot(kind='barh',figsize=(7,35)).invert_yaxis()

# %% [markdown]
# ### Nature of Attack

# %%
df['alternative_txt'].value_counts().plot(kind='barh').invert_yaxis()

# %%
df['multiple'].value_counts().plot(kind='pie',autopct='%1.1f%%',explode=(0,0.1)).invert_yaxis()
plt.title('Multiple Attacks')
# Out:
# Text(0.5, 1.0, 'Multiple Attacks')

# %%
df['success'].value_counts().plot(kind='pie',autopct='%1.1f%%',explode=(0,0.1)).invert_yaxis()
plt.title('Attack Success')
plt.get_cmap('hsv')
plt.show()

# %%
df['suicide'].value_counts().plot(kind='pie',autopct='%1.1f%%',explode=(0,0.1)).invert_yaxis()
plt.title('Suicide Attack')
# Out:
# Text(0.5, 1.0, 'Suicide Attack')

# %%
df['attacktype1_txt'].value_counts().plot(kind='barh').invert_yaxis()

# %% [markdown]
# ### Target of the Attacks

# %%
df['targtype1_txt'].value_counts().plot(kind='barh').invert_yaxis()

# %%
df['targsubtype1_txt'].value_counts().plot(kind='barh',figsize=(7,25)).invert_yaxis()

# %% [markdown]
# ### Nationality of Attacker

# %%
df['natlty2_txt'].value_counts().plot(kind='barh',figsize=(7,35)).invert_yaxis()

# %% [markdown]
# ### How the attack was claimed

# %%
df['claimmode_txt'].value_counts().plot(kind='barh').invert_yaxis()

# %% [markdown]
# ### Weapons Used

# %%
df['weaptype4_txt'].value_counts().plot(kind='pie').invert_yaxis()

# %%
df['weapsubtype4_txt'].value_counts().plot(kind='barh').invert_yaxis()

# %% [markdown]
# ### Damage to Property

# %%
df['propextent_txt'].value_counts().plot(kind='pie',autopct='%1.1f%%').invert_yaxis()

# %% [markdown]
# ### Hostage Analysis

# %%
df['ishostkid'].value_counts().plot(kind='barh').invert_yaxis()
plt.title('Is hostage a child')
# Out:
# Text(0.5, 1.0, 'Is hostage a child')

# %%
df['kidhijcountry'].value_counts().plot(kind='barh',figsize=(7,35)).invert_yaxis()

# %%
df['hostkidoutcome_txt'].value_counts().plot(kind='barh').invert_yaxis()

# %% [markdown]
# ### THANK YOU!
